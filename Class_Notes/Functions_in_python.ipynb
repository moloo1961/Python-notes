# %% [markdown]
# # Functions in Python

# %% [markdown]
# - In Python we have:
#    - User defined functions
#    - Built in functions
#
# - Examples of built-in functions:
#    - '.replace()'
#    - '.count()'
#    - '.index()'

# %%
teams = ["Gor Mahia", "AFC Leopards", "Sofapaka", "Tusker", "Ulinzi Stars"]

# %%
teams.index("Ulinzi Stars")
# Out:
# 4

# %% [markdown]
# ## User Defined Functions

# %% [markdown]
# - We create User defined functions using the def keyword
#
# Syntax for Functions:
#
# def function_name(`paramenter(s) names`): # Parameters are also called arguments
#     logic

# %%
def square(value):
    """"Prints the square of a value"""
    squared_value = value ** 2
    print(squared_value)

square(23)
# Out:
# 529

# %%
def modulous(value):
    """Returns the remainder of a value when divided by 2"""
    remainder_value = value % 2
    return remainder_value

# Always use print with return
num = modulous(23)
print(num)
# Out:
# 1

# %% [markdown]
# - Passing multiple parameters

# %%
def power(base, exponent):
    """Raise the base to the exponent and returns the result"""
    raised_value = base ** exponent
    return raised_value

result = power(10, 3)
print(result)
# Out:
# 1000
