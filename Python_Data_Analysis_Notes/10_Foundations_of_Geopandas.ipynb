# %% [markdown]
# ### Introduction to Geospatial Analysis
#
# If you have ever used Uber to see how close your driver is, used Google Maps to get somewhere, or checked the exact temperature of your location, you are already a beneficiary of Geospatial Analysis! Today, a considerable amount of data generated has a spatial component to it. Outside the rather complex use case of geospatial analysis in a ride sharing app like Uber, geospatial data especially when combined with traditional datasets-such as sales data, can unlock even deeper insights. For example, sales data combined with the store locations can reveal regional purchasing trends or health records combined with hospital locations can reveal gaps in healthcare coverage. In short, geospatial analysis, helps us uncover where things happen and why they happen there , making it a key skill to have as a Data Analyst.
#
# A considerable proportion of the data generated every day is inherently spatial.
#
# From Earth Observation data and GPS data to data included in all kinds of maps, `spatial data`, also known sometimes as `geospatial data` or geographic information, are data for which a specific location is associated with each record.
#
# Every spatial data point can be located on a map.
#
# This can be done using a certain `coordinate reference system`, for example, the `geographical coordinates`, which is based on the usual `latitude-longitude` pairs we use to specify where something is on the globe.
#
# `Geopandas` is an open-source Python library designed to simplify working with geospatial data.
#
# GeoPandas extends the datatypes used by pandas to allow spatial operations on geometric types.
#
# Geometric operations are performed by `shapely`. Geopandas further depends on `pyogrio` for file access and `matplotlib` for plotting.
#
# https://geopandas.org/en/stable/getting_started/introduction.html

# %% [markdown]
# ### Types of Spatial Data
#
# Spatial data can be broadly categorized into two types:
#
# - **Vector Data** Vector data describes features on the Earth's surface using discrete geometries such as points, lines and polygons. Points represent features such as the exact location of a hospital, school, building etc. Lines are used to represent linear features such as roads, rivers, and rail lines. Lastly, polygons represent areas like the boundaries of a country, farm parcels or lakes.
#
#
# - **Raster Data** Raster Data on the other hand represents geographical phenomena as a grid of cells, where each cell holds a specific value.Each cell holds information, often related to continuous phenomena like elevation, temperature, or land cover.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Data Structures
# GeoPandas implements two main data structures, a GeoSeries and a GeoDataFrame. These are subclasses of pandas.Series and pandas.DataFrame, respectively.
#
# #### GeoSeries
# A GeoSeries is a special type of Pandas Series designed to store geometric shapes such as points, lines, or areas instead of just plain text or numbers.
#
# Each row (entry) in a GeoSeries holds one shape — for example:
# - A `Point`: Think of a pin on Google Maps. Example: The exact location of a hospital or shop.
# - A `Polygon`: Represents an enclosed area on the map.e.g A country, park, or lake boundary.
# - A `LineString`: Represents a path or route.e.g A road, river, or hiking trail.
#
# Each row in the GeoSeries can hold either a single shape, or a collection of shapes.
#
# You can have MultiPoints, MultiPolygons, or MultiLineStrings.
#
# #### GeoDataFrame
# A `GeoDataFrame` is a tabular data structure that contains a GeoSeries.
#
# The most important property of a GeoDataFrame is that it always has one `GeoSeries` column that holds a special status - the `active geometry column`.
#
# A GeoDataFrame may also contain other columns with geometrical (shapely) objects, but only one column can be the `active geometry` at a time. To change which column is the active geometry column, use the `GeoDataFrame.set_geometry()` method.
#
# ### Getting Geospatial Datasets
# GeoPandas supports many geospatial file types and makes it easy to read and visualize them.
#
# #### Common Dataset Formats
# - Shapefile (.shp) – Standard GIS format for vector data.
# - GeoJSON – JSON format for encoding geographic data.
# - KML – Used by Google Earth.(Keyhole Markup Language)
# - GPKG (GeoPackage) – Modern SQLite-based format.
# - CSV – Can be converted to GeoDataFrame if it has latitude and longitude columns.

# %% [markdown]
# #### What is a Shapefile?
# A shapefile is a popular file format used for storing geographic vector data—such as points (e.g., cities), lines (e.g., roads), and polygons (e.g., country borders).
#
# A shapefile is not a single file but a group of files that work together. The most common ones are:
#
# - `.shp`: the main file that contains geometry
# - `.shx`: an index file - makes the shape file faster
# - `.dbf`: database (like a table of information), name, population, GDP
# - `.prj`: projection (coordinate system info)
#
# These files must be kept together in the same directory.
#
# #### Installing Python GeoPandas
#
# To use Python GeoPandas, you first have to install it, just like any other Python library.
#
# `pip install geopandas`
#
# It’s important to note that GeoPandas relies on a stack of open-source geospatial libraries to deliver its full spatial potential, including `shapely`, `fiona`, `pyproj`, and `rtree`.
#
# You have to make sure you install all these dependencies, otherwise, GeoPandas may not work as expected.
#
# In any case, if you have troubles during the installation of GeoPandas, you should check the [documentation](https://geopandas.org/en/stable/getting_started/install.html) for further information.
#
# #### Geopandas Libraries
#
# - Shapely is a Python library used for manipulating and analyzing geometric objects —  Built on top of GEOS
# - `fiona` - reading and writing files, geojson
# - `pyproj` - cartographic projections
# - `descartes` - mapping
# - `geopy` - geocoding
# - `rtree` - Spatial analysis
# - `pysal` - more advanced analysis, coloring maps

# %% [markdown]
# ### Reading Spatial Data

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt

# %% [markdown]
# Natural Earth is a public domain map dataset that provides high-quality, free-to-use geospatial data for making maps and conducting geographic analysis.
# Link to dataset: https://www.naturalearthdata.com/

# %%
# load the shapefile
world = gpd.read_file("world_countries/ne_10m_admin_0_countries.shp")

world.head()
# Out:
#         featurecla  scalerank  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 0  Admin-0 country          0          2  Indonesia    IDN         0      2
# 1  Admin-0 country          0          3   Malaysia    MYS         0      2
# 2  Admin-0 country          0          2      Chile    CHL         0      2
# 3  Admin-0 country          0          3    Bolivia    BOL         0      2
# 4  Admin-0 country          0          2       Peru    PER         0      2
#
#                 TYPE TLC      ADMIN  ... FCLASS_TR  FCLASS_ID FCLASS_PL  \
# 0  Sovereign country   1  Indonesia  ...       NaN        NaN       NaN
# 1  Sovereign country   1   Malaysia  ...       NaN        NaN       NaN
# 2  Sovereign country   1      Chile  ...       NaN        NaN       NaN
# 3  Sovereign country   1    Bolivia  ...       NaN        NaN       NaN
# 4  Sovereign country   1       Peru  ...       NaN        NaN       NaN
#
#   FCLASS_GR  FCLASS_IT FCLASS_NL FCLASS_SE  FCLASS_BD FCLASS_UA  \
# 0       NaN        NaN       NaN       NaN        NaN       NaN
# 1       NaN        NaN       NaN       NaN        NaN       NaN
# 2       NaN        NaN       NaN       NaN        NaN       NaN
# 3       NaN        NaN       NaN       NaN        NaN       NaN
# 4       NaN        NaN       NaN       NaN        NaN       NaN
#
#                                             geometry
# 0  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2  MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3  POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4  MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...
#
# [5 rows x 169 columns]

# %% [markdown]
# | Column      | Description                                                                 |
# |-------------|-----------------------------------------------------------------------------|
# | featurecla  | Feature class — describes the feature type, like "Admin-0 country" (country-level boundary). |
# | scalerank   | Rank for map generalization; lower = more important (for display at small scales). |
# | LABELRANK   | Rank used for labeling features in maps — lower = higher priority.          |
# | SOVEREIGNT  | The sovereign nation name (e.g., "Indonesia").                              |
# | SOV_A3      | 3-letter country code for the sovereign nation (e.g., "IDN").               |
# | ADM0_DIF    | Indicates if ADMIN and SOVEREIGNT differ. 0 = same, 1 = different.          |
# | LEVEL       | Administrative level — 2 usually means country-level (Admin-0).             |
# | TYPE        | Type of entity — often "Sovereign country" or "Disputed".                   |
# | TLC         | Could indicate territory label category (less commonly used).               |
# | ADMIN       | Official administrative name of the country.                                |

# %%
#plot the world map
world.plot()
# Out:
# <Axes: >

# %%
# check the type
print(type(world))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
# view columns
print(world.columns)
# Out:
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'TLC', 'ADMIN',
#        ...
#        'FCLASS_TR', 'FCLASS_ID', 'FCLASS_PL', 'FCLASS_GR', 'FCLASS_IT',
#        'FCLASS_NL', 'FCLASS_SE', 'FCLASS_BD', 'FCLASS_UA', 'geometry'],
#       dtype='str', length=169)

# %%
world.geometry.head()
# Out:
# 0    MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1    MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2    MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3    POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4    MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...
# Name: geometry, dtype: geometry

# %%
world['geometry'].head()
# Out:
# 0    MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1    MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2    MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3    POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4    MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...
# Name: geometry, dtype: geometry

# %%
world.geom_type.value_counts()
# Out:
# MultiPolygon    151
# Polygon         107
# Name: count, dtype: int64

# %%
# Access the specific geometry of a country
country_shape = world.geometry.iloc[0]

# Create a plot of the specific country
plt.Figure(figsize=(10, 8))

# Plot the country shape
gpd.GeoSeries(country_shape).plot()
# Out:
# <Axes: >

# %%
kenya = world[world['ADMIN'] == 'Kenya']
kenya.plot()
# kenya_shape = kenya.geometry
# gpd.GeoSeries(kenya_shape).plot()
# Out:
# <Axes: >

# %%
world['ADMIN'].unique()
# Out:
# <StringArray>
# [                   'Indonesia',                     'Malaysia',
#                         'Chile',                      'Bolivia',
#                          'Peru',                    'Argentina',
#  'Dhekelia Sovereign Base Area',                       'Cyprus',
#                         'India',                        'China',
#  ...
#      'Northern Mariana Islands',                      'Bahrain',
#             'Coral Sea Islands',              'Spratly Islands',
#             'Clipperton Island',                  'Macao S.A.R',
#   'Ashmore and Cartier Islands', 'Bajo Nuevo Bank (Petrel Is.)',
#               'Serranilla Bank',             'Scarborough Reef']
# Length: 258, dtype: str

# %%
# Check the type
print(type(world))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
# View columns
print(world.columns)
# Out:
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'TLC', 'ADMIN',
#        ...
#        'FCLASS_TR', 'FCLASS_ID', 'FCLASS_PL', 'FCLASS_GR', 'FCLASS_IT',
#        'FCLASS_NL', 'FCLASS_SE', 'FCLASS_BD', 'FCLASS_UA', 'geometry'],
#       dtype='str', length=169)

# %% [markdown]
# #### Accessing the Geometry Column

# %%
# Access geometry
world.geometry.head()
# Out:
# 0    MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1    MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2    MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3    POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4    MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...
# Name: geometry, dtype: geometry

# %%
world.geometry.extract_unique_points()
# world.geometry.unique()
# Out:
# 0      MULTIPOINT ((117.70361 4.16341), (117.70361 4....
# 1      MULTIPOINT ((117.70361 4.16341), (117.69711 4....
# 2      MULTIPOINT ((-69.51009 -17.50659), (-69.50611 ...
# 3      MULTIPOINT ((-69.51009 -17.50659), (-69.51009 ...
# 4      MULTIPOINT ((-69.51009 -17.50659), (-69.63832 ...
#                              ...
# 253    MULTIPOINT ((113.5586 22.16303), (113.56943 22...
# 254    MULTIPOINT ((123.59702 -12.42832), (123.59775 ...
# 255    MULTIPOINT ((-79.98929 15.79495), (-79.98782 1...
# 256    MULTIPOINT ((-78.63707 15.86209), (-78.64041 1...
# 257    MULTIPOINT ((117.75389 15.15437), (117.75569 1...
# Length: 258, dtype: geometry

# %%
# Access a specific geometry
# Select the first country's shape
country_shape = world.geometry.iloc[0]
# Create a larger plot
plt.figure(figsize=(10, 8))  
# Plot the shape using a GeoSeries
gpd.GeoSeries([country_shape]).plot()
# Out:
# <Axes: >

# %% [markdown]
# #### Activity 1: Country Geometry Viewer
#
# - Pick a country from the GeoDataFrame.
# - Access and plot its shape.

# %%
world['ADMIN'].unique()  # Unique country names
# Out:
# <StringArray>
# [                   'Indonesia',                     'Malaysia',
#                         'Chile',                      'Bolivia',
#                          'Peru',                    'Argentina',
#  'Dhekelia Sovereign Base Area',                       'Cyprus',
#                         'India',                        'China',
#  ...
#      'Northern Mariana Islands',                      'Bahrain',
#             'Coral Sea Islands',              'Spratly Islands',
#             'Clipperton Island',                  'Macao S.A.R',
#   'Ashmore and Cartier Islands', 'Bajo Nuevo Bank (Petrel Is.)',
#               'Serranilla Bank',             'Scarborough Reef']
# Length: 258, dtype: str

# %%
#Example: Select Kenya
kenya = world[world['ADMIN'] == 'Kenya']
kenya.plot()
# Out:
# <Axes: >

# %% [markdown]
#  #### Activity 2: Geometry Type Checker
#  Check the type of geometries in the dataset.

# %%
world.geom_type.value_counts()
# Out:
# MultiPolygon    151
# Polygon         107
# Name: count, dtype: int64

# %% [markdown]
# ### Customizing map styles with geopandas

# %%
ax = world.plot(figsize=(10, 5), cmap='Set3', edgecolor='white')
ax.axis('off')
plt.show()

# %%
world.plot(figsize=(10,5))
# Out:
# <Axes: >

# %%
ax = world.plot(figsize=(20,20))
ax.axis('off')
plt.show()

# %%
#coloring maps
# 1.fill - inside
# 2.edge - outline
ax = world.plot(figsize=(20,20), color = 'grey', edgecolor='white')
ax.axis('off')
plt.show()

# %%
ax = world.plot(figsize=(20,20), cmap= 'Set3')
ax.axis('off')
plt.show()

# %%
ax = world.plot(figsize=(20,20), color = '#CCCCCC', edgecolor='#FF0000', linewidth=3)
ax.axis('off')
plt.show()

# %%
ax = world.plot(figsize=(20,20), color = '#CCCCCC', edgecolor='#FF0000', linewidth=0.5)
ax.axis('off')
plt.show()

# %% [markdown]
# ## When Do We Use GeoPandas?
#
# You use **GeoPandas** when you're working with **spatial data** any data that includes a geographic component. Typical scenarios include:
#
# ### 1. Mapping and Visualizing Geographic Data
# - Plotting maps of countries, cities, or other regions.
# - **Example:** Visualizing population density across African countries.
#
#
# ### 2. Spatial Analysis
# - Calculating areas, distances, centroids, or bounding boxes.
# - **Example:** Finding the area of forest cover in each country.
#
# ### 3. Working with Shapefiles or GeoJSON
# - Reading `.shp`, `.geojson`, `.kml`, or other geographic file formats.
# - **Example:** Loading shapefiles of Nairobi's wards for mapping or analysis.
#
# ### 4. Filtering or Joining by Location
# - Finding all schools within a 5 km radius of a hospital.
# - Joining datasets based on spatial location, like “which county each point belongs to.”
#
# ### 5. Coordinate Reference System (CRS) Handling
# - Converting between different map projections.
# - **Example:** Reprojecting data from WGS84 (lat/lon) to UTM.

# %% [markdown]
# ### Mapping and plotting tools
#
# GeoPandas provides a high-level interface to the matplotlib library for making maps. Mapping shapes is as easy as using the plot() method on a GeoSeries or GeoDataFrame.
#
# link to data: https://github.com/geopandas/geodatasets/blob/main/geodatasets/json/database.json

# %%
import geodatasets

# %%
airbnb = gpd.read_file(geodatasets.get_path('geoda.airbnb'))
airbnb.head()
# Out:
# Downloading file 'airbnb.zip' from 'https://geodacenter.github.io/data-and-lab//data/airbnb.zip' to 'C:\Users\User\AppData\Local\geodatasets\geodatasets\Cache'.
#          community     shape_area      shape_len  AREAID  response_r  \
# 0          DOUGLAS  46004621.1581  31027.0545098      35   98.771429
# 1          OAKLAND  16913961.0408  19565.5061533      36   99.200000
# 2      FULLER PARK  19916704.8692           None      37   68.000000
# 3  GRAND BOULEVARD  48492503.1554  28196.8371573      38   94.037037
# 4          KENWOOD  29071741.9283  23325.1679062      39   92.542857
#
#     accept_r  rev_rating    price_pp  room_type  num_spots  ...  crowded  \
# 0  94.514286   87.777778   78.157895   1.789474         38  ...      1.8
# 1  90.105263   88.812500   53.775000   1.850000         20  ...      1.3
# 2        NaN   91.750000   84.000000   1.833333          6  ...      3.2
# 3  83.615385   92.750000  119.533333   1.533333         30  ...      3.3
# 4  88.142857   90.656250   77.991453   1.615385         39  ...      2.4
#
#    dependency  without_hs  unemployed  income_pc  harship_in  num_crimes  \
# 0        30.7        14.3        18.2      23791          47        5013
# 1        40.4        18.4        28.7      19252          78        1306
# 2        44.9        26.6        33.9      10432          97        1764
# 3        39.5        15.9        24.3      23472          57        6416
# 4        35.4        11.3        15.7      35911          26        2713
#
#    num_theft  population                                           geometry
# 0       1241       18238  POLYGON ((-87.60914 41.84469, -87.60915 41.844...
# 1        311        5918  POLYGON ((-87.59215 41.81693, -87.59231 41.816...
# 2        383        2876  POLYGON ((-87.6288 41.80189, -87.62879 41.8017...
# 3       1428       21929  POLYGON ((-87.60671 41.81681, -87.6067 41.8165...
# 4        654       17841  POLYGON ((-87.59215 41.81693, -87.59215 41.816...
#
# [5 rows x 21 columns]

# %%
airbnb.plot()
# Out:
# <Axes: >

# %%
#chicago.head()
airbnb.head()
# Out:
#          community     shape_area      shape_len  AREAID  response_r  \
# 0          DOUGLAS  46004621.1581  31027.0545098      35   98.771429
# 1          OAKLAND  16913961.0408  19565.5061533      36   99.200000
# 2      FULLER PARK  19916704.8692            NaN      37   68.000000
# 3  GRAND BOULEVARD  48492503.1554  28196.8371573      38   94.037037
# 4          KENWOOD  29071741.9283  23325.1679062      39   92.542857
#
#     accept_r  rev_rating    price_pp  room_type  num_spots  ...  crowded  \
# 0  94.514286   87.777778   78.157895   1.789474         38  ...      1.8
# 1  90.105263   88.812500   53.775000   1.850000         20  ...      1.3
# 2        NaN   91.750000   84.000000   1.833333          6  ...      3.2
# 3  83.615385   92.750000  119.533333   1.533333         30  ...      3.3
# 4  88.142857   90.656250   77.991453   1.615385         39  ...      2.4
#
#    dependency  without_hs  unemployed  income_pc  harship_in  num_crimes  \
# 0        30.7        14.3        18.2      23791          47        5013
# 1        40.4        18.4        28.7      19252          78        1306
# 2        44.9        26.6        33.9      10432          97        1764
# 3        39.5        15.9        24.3      23472          57        6416
# 4        35.4        11.3        15.7      35911          26        2713
#
#    num_theft  population                                           geometry
# 0       1241       18238  POLYGON ((-87.60914 41.84469, -87.60915 41.844...
# 1        311        5918  POLYGON ((-87.59215 41.81693, -87.59231 41.816...
# 2        383        2876  POLYGON ((-87.6288 41.80189, -87.62879 41.8017...
# 3       1428       21929  POLYGON ((-87.60671 41.81681, -87.6067 41.8165...
# 4        654       17841  POLYGON ((-87.59215 41.81693, -87.59215 41.816...
#
# [5 rows x 21 columns]

# %%
airbnb.plot()
# Out:
# <Axes: >

# %% [markdown]
# #### Choropleth maps
# GeoPandas makes it easy to create Choropleth maps (maps where the color of each shape is based on the value of an associated variable).
#
# Simply use the plot command with the column argument set to the column whose values you want used to assign colors.

# %%
# Plot by population
airbnb.plot(
    column = 'population', 
    legend=True, 
    legend_kwds={'label': "Population by Area"},
    cmap='plasma')
# Out:
# <Axes: >

# %%
#Plot by population
airbnb.plot(column="population")
# Out:
# <Axes: >

# %% [markdown]
# ### Creating a legend
# When plotting a map, we can enable a legend using the legend argument:

# %%
#Plot population estimates with an accurate legend
airbnb.plot(column='population', legend=True)
# Out:
# <Axes: >

# %%
# adds its label using using legend_kwds
airbnb.plot(
    column="population",
    legend=True,
    legend_kwds={"label": "Population by Area"},
)
# Out:
# <Axes: >

# %% [markdown]
# ### Choosing colors
# - You can also modify the colors used by plot() with the cmap option.
# - For a full list of colormaps, https://matplotlib.org/stable/users/explain/colors/colormaps.html.

# %% [markdown]
# #### Sequential (Good for ordered/numeric data like population, income)
# Use when values have a natural order (low to high).
# - 'viridis' (default and perceptually uniform)
# - 'plasma'
# - 'inferno'
# - 'magma'
# - 'cividis'
# - 'Blues', 'Greens', 'Reds', 'Purples'
# - 'YlOrRd', 'OrRd', 'BuPu', 'YlGnBu'

# %%
airbnb.boundary.plot()
# Out:
# <Axes: >

# %%
airbnb.plot(column='population', cmap='magma', legend=True)
# Out:
# <Axes: >

# %%
plt.colormaps()
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'berlin',
#  'managua',
#  'vanimo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
#  'Set1',
#  'Set2',
#  'Set3',
#  'tab10',
#  'tab20',
#  'tab20b',
#  'tab20c',
#  'grey',
#  'gist_grey',
#  'gist_yerg',
#  'Grays',
#  'magma_r',
#  'inferno_r',
#  'plasma_r',
#  'viridis_r',
#  'cividis_r',
#  'twilight_r',
#  'twilight_shifted_r',
#  'turbo_r',
#  'berlin_r',
#  'managua_r',
#  'vanimo_r',
#  'Blues_r',
#  'BrBG_r',
#  'BuGn_r',
#  'BuPu_r',
#  'CMRmap_r',
#  'GnBu_r',
#  'Greens_r',
#  'Greys_r',
#  'OrRd_r',
#  'Oranges_r',
#  'PRGn_r',
#  'PiYG_r',
#  'PuBu_r',
#  'PuBuGn_r',
#  'PuOr_r',
#  'PuRd_r',
#  'Purples_r',
#  'RdBu_r',
#  'RdGy_r',
#  'RdPu_r',
#  'RdYlBu_r',
#  'RdYlGn_r',
#  'Reds_r',
#  'Spectral_r',
#  'Wistia_r',
#  'YlGn_r',
#  'YlGnBu_r',
#  'YlOrBr_r',
#  'YlOrRd_r',
#  'afmhot_r',
#  'autumn_r',
#  'binary_r',
#  'bone_r',
#  'brg_r',
#  'bwr_r',
#  'cool_r',
#  'coolwarm_r',
#  'copper_r',
#  'cubehelix_r',
#  'flag_r',
#  'gist_earth_r',
#  'gist_gray_r',
#  'gist_heat_r',
#  'gist_ncar_r',
#  'gist_rainbow_r',
#  'gist_stern_r',
#  'gist_yarg_r',
#  'gnuplot_r',
#  'gnuplot2_r',
#  'gray_r',
#  'hot_r',
#  'hsv_r',
#  'jet_r',
#  'nipy_spectral_r',
#  'ocean_r',
#  'pink_r',
#  'prism_r',
#  'rainbow_r',
#  'seismic_r',
#  'spring_r',
#  'summer_r',
#  'terrain_r',
#  'winter_r',
#  'Accent_r',
#  'Dark2_r',
#  'Paired_r',
#  'Pastel1_r',
#  'Pastel2_r',
#  'Set1_r',
#  'Set2_r',
#  'Set3_r',
#  'tab10_r',
#  'tab20_r',
#  'tab20b_r',
#  'tab20c_r',
#  'grey_r',
#  'gist_grey_r',
#  'gist_yerg_r',
#  'Grays_r']

# %%
# To make the color transparent for when you just want to show the boundary,
#chicago.plot(facecolor="none", edgecolor="black")
#airbnb.plot(facecolor="none")
airbnb.boundary.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### choropleth classification schemes
#
# Data classification is the process of grouping continuous or numeric data into discrete categories (or classes) so that they can be visually represented with different colors or shades in a choropleth map.
#
# In libraries like GeoPandas and matplotlib, when you create a choropleth map, you can use the scheme option (powered by the mapclassify package) to control how the values are divided into color bins.
#
# #### Examples of Classification Schemes (`mapclassify`)
#
# Some common classification schemes available via `mapclassify`:
#
# | Scheme           | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | `equal_interval` | Divides data range into equal-sized intervals.                             |
# | `quantiles`      | Each class contains the same number of observations.                       |               |
# | `box_plot`       | Based on quartiles and outliers, like in a box plot.                       |
# | `std_mean`       | Classification based on standard deviations from the mean.                |
# | `fisher_jenks`   | Minimizes variance within classes, maximizes variance between classes.     |

# %%
airbnb.plot(column='population', cmap='OrRd', scheme='quantiles')
# Out:
# <Axes: >

# %% [markdown]
# ### Interactive mapping
#
# Geopandas can create interactive maps based on the folium library.
#
# pip install folium branca
#
# - Folium: Folium is a Python library that enables the creation of interactive maps, leveraging the capabilities of the Leaflet JavaScript library.
# - Branca: A helper library used by Folium to handle tooltips, legends, color maps, and popups.

# %%
import folium

# %%
atlanta = gpd.read_file(geodatasets.get_path('geoda.atlanta'))
atlanta.head()
# Out:
# Downloading file 'atlanta_hom.zip' from 'https://geodacenter.github.io/data-and-lab//data/atlanta_hom.zip' to 'C:\Users\User\AppData\Local\geodatasets\geodatasets\Cache'.
# Extracting 'atlanta_hom/atl_hom.geojson' from 'C:\Users\User\AppData\Local\geodatasets\geodatasets\Cache\atlanta_hom.zip' to 'C:\Users\User\AppData\Local\geodatasets\geodatasets\Cache\atlanta_hom.zip.unzip'
#         NAME      STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  STFIPS  COFIPS  \
# 0   Cherokee  North Carolina         37       039  37039      37      39
# 1       Polk       Tennessee         47       139  47139      47     139
# 2     Oconee  South Carolina         45       073  45073      45      73
# 3      Rabun         Georgia         13       241  13241      13     241
# 4  Whitfield         Georgia         13       313  13313      13     313
#
#    FIPSNO     HR7983    HR8587  ...  PO7983  PO8587  PO8995      PE77  \
# 0   37039   6.298816  6.742065  ...   95256   59329  144758  2.933480
# 1   47139  13.271204  9.629968  ...   67816   41537   97210  4.422696
# 2   45073  14.174115  6.246720  ...  246929  160084  413465  3.716055
# 3   13241  13.306214  6.038830  ...   52607   33119   83962  2.637461
# 4   13313  10.274169  6.715627  ...  330927  208469  524696  4.099088
#
#        PE82      PE87    RDAC80    RDAC85    RDAC90  \
# 0  1.605377  1.922455  0.897757  0.444341  0.134578
# 1  3.994711  3.833682 -0.012454 -0.140179 -0.192610
# 2  3.635228  3.789255 -0.168537 -0.311719 -0.368479
# 3  2.625957  4.394626  0.449209  0.058768 -0.229536
# 4  2.877935  2.452316 -0.318807 -0.476584 -0.566740
#
#                                             geometry
# 0  POLYGON ((-84.29104 35.21054, -84.22594 35.261...
# 1  POLYGON ((-84.29104 35.21054, -84.32385 34.989...
# 2  POLYGON ((-83.05512 34.48996, -83.07915 34.518...
# 3  POLYGON ((-83.3508 34.70955, -83.39137 34.7288...
# 4  POLYGON ((-85.047 34.62268, -85.04798 34.71451...
#
# [5 rows x 24 columns]

# %%
atlanta.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c675ed38e896786f40f97397ba60ea1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c675ed38e896786f40f97397ba60ea1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c675ed38e896786f40f97397ba60ea1 = L.map(
#                 &quot;map_2c675ed38e896786f40f97397ba60ea1&quot;,
#                 {
#                     center: [33.7135467529297, -84.49272155761719],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_2c675ed38e896786f40f97397ba60ea1);
#
#
#
#
#
#             var tile_layer_64956a4b5803b756c49ed724f8e6710e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_64956a4b5803b756c49ed724f8e6710e.addTo(map_2c675ed38e896786f40f97397ba60ea1);
#
#
#             map_2c675ed38e896786f40f97397ba60ea1.fitBounds(
#                 [[32.1345710754395, -86.4989700317383], [35.2925224304199, -82.4864730834961]],
#                 {}
#             );
#
#
#         function geo_json_9f0f307bbebfd5065e8b407ab5e339bb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_9f0f307bbebfd5065e8b407ab5e339bb_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_9f0f307bbebfd5065e8b407ab5e339bb_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_9f0f307bbebfd5065e8b407ab5e339bb_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_9f0f307bbebfd5065e8b407ab5e339bb_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_9f0f307bbebfd5065e8b407ab5e339bb.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_9f0f307bbebfd5065e8b407ab5e339bb_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_9f0f307bbebfd5065e8b407ab5e339bb = L.geoJson(null, {
#                 onEachFeature: geo_json_9f0f307bbebfd5065e8b407ab5e339bb_onEachFeature,
#
#                 style: geo_json_9f0f307bbebfd5065e8b407ab5e339bb_styler,
#                 pointToLayer: geo_json_9f0f307bbebfd5065e8b407ab5e339bb_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_9f0f307bbebfd5065e8b407ab5e339bb_add (data) {
#             geo_json_9f0f307bbebfd5065e8b407ab5e339bb
#                 .addData(data);
#         }
#             geo_json_9f0f307bbebfd5065e8b407ab5e339bb_add({&quot;bbox&quot;: [-86.4989700317383, 32.1345710754395, -82.4864730834961, 35.2925224304199], &quot;features&quot;: [{&quot;bbox&quot;: [-84.3238525390625, 34.988224029541, -83.6956329345703, 35.2925224304199], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-84.2910385131836, 35.2105445861816], [-84.225944519043, 35.261604309082], [-84.1797256469727, 35.2409896850586], [-84.1016464233398, 35.2455520629883], [-84.0427780151367, 35.27257

# %%
atlanta.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NAME        90 non-null     str
#  1   STATE_NAME  90 non-null     str
#  2   STATE_FIPS  90 non-null     str
#  3   CNTY_FIPS   90 non-null     str
#  4   FIPS        90 non-null     str
#  5   STFIPS      90 non-null     int32
#  6   COFIPS      90 non-null     int32
#  7   FIPSNO      90 non-null     int32
#  8   HR7983      90 non-null     float64
#  9   HR8587      90 non-null     float64
#  10  HR8995      90 non-null     float64
#  11  HC7983      90 non-null     int32
#  12  HC8587      90 non-null     int32
#  13  HC8995      90 non-null     int32
#  14  PO7983      90 non-null     int32
#  15  PO8587      90 non-null     int32
#  16  PO8995      90 non-null     int32
#  17  PE77        90 non-null     float64
#  18  PE82        90 non-null     float64
#  19  PE87        90 non-null     float64
#  20  RDAC80      90 non-null     float64
#  21  RDAC85      90 non-null     float64
#  22  RDAC90      90 non-null     float64
#  23  geometry    90 non-null     geometry
# dtypes: float64(9), geometry(1), int32(9), str(5)
# memory usage: 13.8 KB

# %%
atlanta.explore(
    column="HR7983",               
    cmap="Reds",                  
    legend=True,                  
    tooltip=["NAME", "HR7983"],   
    style_kwds={"fillOpacity": 0.8, "weight": 0.8},
    highlight=False
 )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28ca3f1223a077e50a1b966cea3de55a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28ca3f1223a077e50a1b966cea3de55a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28ca3f1223a077e50a1b966cea3de55a = L.map(
#                 &quot;map_28ca3f1223a077e50a1b966cea3de55a&quot;,
#                 {
#                     center: [33.7135467529297, -84.49272155761719],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_28ca3f1223a077e50a1b966cea3de55a);
#
#
#
#
#
#             var tile_layer_f2e75a0938104d6908e7b4444c56b77e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f2e75a0938104d6908e7b4444c56b77e.addTo(map_28ca3f1223a077e50a1b966cea3de55a);
#
#
#             map_28ca3f1223a077e50a1b966cea3de55a.fitBounds(
#                 [[32.1345710754395, -86.4989700317383], [35.2925224304199, -82.4864730834961]],
#                 {}
#             );
#
#
#         function geo_json_4a1348521e80bfa82179bbaf4adb413a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#fed9c9&quot;, &quot;fillColor&quot;: &quot;#fed9c9&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;1&quot;: case &quot;3&quot;: case &quot;40&quot;:
#                     return {&quot;color&quot;: &quot;#fc8565&quot;, &quot;fillColor&quot;: &quot;#fc8565&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#fb7a5a&quot;, &quot;fillColor&quot;: &quot;#fb7a5a&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#fcaa8d&quot;, &quot;fillColor&quot;: &quot;#fcaa8d&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;5&quot;: case &quot;29&quot;:
#                     return {&quot;color&quot;: &quot;#fb7d5d&quot;, &quot;fillColor&quot;: &quot;#fb7d5d&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#fcab8f&quot;, &quot;fillColor&quot;: &quot;#fcab8f&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#ffeee7&quot;, &quot;fillColor&quot;: &quot;#ffeee7&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;8&quot;: case &quot;34&quot;:
#                     return {&quot;color&quot;: &quot;#fee9df&quot;, &quot;fillColor&quot;: &quot;#fee9df&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#fdccb8&quot;, &quot;fillColor&quot;: &quot;#fdccb8&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#ffede5&quot;, &quot;fillColor&quot;: &quot;#ffede5&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#fc9777&quot;, &quot;fillColor&quot;: &quot;#fc9777&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;13&quot;: case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;#ffebe2&quot;, &quot;fillColor&quot;: &quot;#ffebe2&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#fcb99f&quot;, &quot;fillColor&quot;: &quot;#fcb99f&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.8};
#                 case &quot;15&quot;: case &quot;3

# %%
# Load the Atlanta homicide dataset using its registered name
atlanta = gpd.read_file(geodatasets.get_path("geoda.atlanta"))

# %%
# View the first few rows
atlanta.head()
# Out:
#         NAME      STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  STFIPS  COFIPS  \
# 0   Cherokee  North Carolina         37       039  37039      37      39
# 1       Polk       Tennessee         47       139  47139      47     139
# 2     Oconee  South Carolina         45       073  45073      45      73
# 3      Rabun         Georgia         13       241  13241      13     241
# 4  Whitfield         Georgia         13       313  13313      13     313
#
#    FIPSNO     HR7983    HR8587  ...  PO7983  PO8587  PO8995      PE77  \
# 0   37039   6.298816  6.742065  ...   95256   59329  144758  2.933480
# 1   47139  13.271204  9.629968  ...   67816   41537   97210  4.422696
# 2   45073  14.174115  6.246720  ...  246929  160084  413465  3.716055
# 3   13241  13.306214  6.038830  ...   52607   33119   83962  2.637461
# 4   13313  10.274169  6.715627  ...  330927  208469  524696  4.099088
#
#        PE82      PE87    RDAC80    RDAC85    RDAC90  \
# 0  1.605377  1.922455  0.897757  0.444341  0.134578
# 1  3.994711  3.833682 -0.012454 -0.140179 -0.192610
# 2  3.635228  3.789255 -0.168537 -0.311719 -0.368479
# 3  2.625957  4.394626  0.449209  0.058768 -0.229536
# 4  2.877935  2.452316 -0.318807 -0.476584 -0.566740
#
#                                             geometry
# 0  POLYGON ((-84.29104 35.21054, -84.22594 35.261...
# 1  POLYGON ((-84.29104 35.21054, -84.32385 34.989...
# 2  POLYGON ((-83.05512 34.48996, -83.07915 34.518...
# 3  POLYGON ((-83.3508 34.70955, -83.39137 34.7288...
# 4  POLYGON ((-85.047 34.62268, -85.04798 34.71451...
#
# [5 rows x 24 columns]

# %%
atlanta.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f1b29a81f7d2a5c83c5cea5e5bc7fac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f1b29a81f7d2a5c83c5cea5e5bc7fac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f1b29a81f7d2a5c83c5cea5e5bc7fac = L.map(
#                 &quot;map_0f1b29a81f7d2a5c83c5cea5e5bc7fac&quot;,
#                 {
#                     center: [33.7135467529297, -84.49272155761719],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0f1b29a81f7d2a5c83c5cea5e5bc7fac);
#
#
#
#
#
#             var tile_layer_264cc76d6cde1f19238fe061ad03227d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_264cc76d6cde1f19238fe061ad03227d.addTo(map_0f1b29a81f7d2a5c83c5cea5e5bc7fac);
#
#
#             map_0f1b29a81f7d2a5c83c5cea5e5bc7fac.fitBounds(
#                 [[32.1345710754395, -86.4989700317383], [35.2925224304199, -82.4864730834961]],
#                 {}
#             );
#
#
#         function geo_json_1fc16efcd8234008c18335939425b6bf_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1fc16efcd8234008c18335939425b6bf_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1fc16efcd8234008c18335939425b6bf_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_1fc16efcd8234008c18335939425b6bf_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1fc16efcd8234008c18335939425b6bf_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_1fc16efcd8234008c18335939425b6bf.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1fc16efcd8234008c18335939425b6bf_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1fc16efcd8234008c18335939425b6bf = L.geoJson(null, {
#                 onEachFeature: geo_json_1fc16efcd8234008c18335939425b6bf_onEachFeature,
#
#                 style: geo_json_1fc16efcd8234008c18335939425b6bf_styler,
#                 pointToLayer: geo_json_1fc16efcd8234008c18335939425b6bf_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_1fc16efcd8234008c18335939425b6bf_add (data) {
#             geo_json_1fc16efcd8234008c18335939425b6bf
#                 .addData(data);
#         }
#             geo_json_1fc16efcd8234008c18335939425b6bf_add({&quot;bbox&quot;: [-86.4989700317383, 32.1345710754395, -82.4864730834961, 35.2925224304199], &quot;features&quot;: [{&quot;bbox&quot;: [-84.3238525390625, 34.988224029541, -83.6956329345703, 35.2925224304199], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-84.2910385131836, 35.2105445861816], [-84.225944519043, 35.261604309082], [-84.1797256469727, 35.2409896850586], [-84.1016464233398, 35.2455520629883], [-84.0427780151367, 35.27257

# %%
# customised choropleth map
atlanta.explore(
    column="HR7983",               
    cmap="Reds",                   # Color map for intensity
    legend=True,                  
    tooltip=["NAME", "HR7983"],    # Tooltip shows county name + homicide rate
    style_kwds={"fillOpacity": 0.9, "weight": 0.8}, #weight : thickness of the polygon borders
    highlight=False
 ) # adds a visual effect to the map so that when your mouse hovers over a region, that region stands out.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c2392851a79f7903dffb79829395e39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c2392851a79f7903dffb79829395e39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c2392851a79f7903dffb79829395e39 = L.map(
#                 &quot;map_5c2392851a79f7903dffb79829395e39&quot;,
#                 {
#                     center: [33.7135467529297, -84.49272155761719],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_5c2392851a79f7903dffb79829395e39);
#
#
#
#
#
#             var tile_layer_70fc4ab3e1674b2e0417dc3e2b803e4f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70fc4ab3e1674b2e0417dc3e2b803e4f.addTo(map_5c2392851a79f7903dffb79829395e39);
#
#
#             map_5c2392851a79f7903dffb79829395e39.fitBounds(
#                 [[32.1345710754395, -86.4989700317383], [35.2925224304199, -82.4864730834961]],
#                 {}
#             );
#
#
#         function geo_json_6f26fe85d0a58a324d4dff60ef7516d5_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#fed9c9&quot;, &quot;fillColor&quot;: &quot;#fed9c9&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;1&quot;: case &quot;3&quot;: case &quot;40&quot;:
#                     return {&quot;color&quot;: &quot;#fc8565&quot;, &quot;fillColor&quot;: &quot;#fc8565&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#fb7a5a&quot;, &quot;fillColor&quot;: &quot;#fb7a5a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#fcaa8d&quot;, &quot;fillColor&quot;: &quot;#fcaa8d&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;5&quot;: case &quot;29&quot;:
#                     return {&quot;color&quot;: &quot;#fb7d5d&quot;, &quot;fillColor&quot;: &quot;#fb7d5d&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#fcab8f&quot;, &quot;fillColor&quot;: &quot;#fcab8f&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#ffeee7&quot;, &quot;fillColor&quot;: &quot;#ffeee7&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;8&quot;: case &quot;34&quot;:
#                     return {&quot;color&quot;: &quot;#fee9df&quot;, &quot;fillColor&quot;: &quot;#fee9df&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#fdccb8&quot;, &quot;fillColor&quot;: &quot;#fdccb8&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#ffede5&quot;, &quot;fillColor&quot;: &quot;#ffede5&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#fc9777&quot;, &quot;fillColor&quot;: &quot;#fc9777&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;13&quot;: case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;#ffebe2&quot;, &quot;fillColor&quot;: &quot;#ffebe2&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#fcb99f&quot;, &quot;fillColor&quot;: &quot;#fcb99f&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 0.8};
#                 case &quot;15&quot;: case &quot;3

# %% [markdown]
# #### Creating a Folium Map

# %%
map_centre = [atlanta.geometry.centroid.y.mean(), atlanta.geometry.centroid.x.mean()]
m = folium.Map(location= map_centre, zoom_start=6)
m
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13364\2564094350.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   map_centre = [atlanta.geometry.centroid.y.mean(), atlanta.geometry.centroid.x.mean()]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42671371306d4942a94e93ee3b7a5016 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42671371306d4942a94e93ee3b7a5016&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42671371306d4942a94e93ee3b7a5016 = L.map(
#                 &quot;map_42671371306d4942a94e93ee3b7a5016&quot;,
#                 {
#                     center: [33.74719839929067, -84.26267418366155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfc117086215924fff9f433386c27bc0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfc117086215924fff9f433386c27bc0.addTo(map_42671371306d4942a94e93ee3b7a5016);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Get the top 5 counties by homicide rate
top5 = atlanta.nlargest(5, 'HR8995')

# Marker for the top 5 counties
for _, row in top5.iterrows():
    location = [row.geometry.centroid.y, row.geometry.centroid.x]
    rate = row['HR8995']
    name = row['NAME']

    folium.CircleMarker(
        location = location,
        radius = 5 + rate / 5,
        color = 'crimson', 
        fill= True,
        fill_color = 'crimson', 
        fill_opacity = 0.8
    ).add_to(m)

    m

# %%
# Create a base map centered around the average location of the counties
# centroid (center point) of each polygon (like a county or district) in atlanta.
map_center = [atlanta.geometry.centroid.y.mean(), atlanta.geometry.centroid.x.mean()]
m = folium.Map(location=map_center, zoom_start=6)
m
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13364\3476393867.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   map_center = [atlanta.geometry.centroid.y.mean(), atlanta.geometry.centroid.x.mean()]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5dc368ab07deca2b0065c2f23216abaa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5dc368ab07deca2b0065c2f23216abaa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5dc368ab07deca2b0065c2f23216abaa = L.map(
#                 &quot;map_5dc368ab07deca2b0065c2f23216abaa&quot;,
#                 {
#                     center: [33.74719839929067, -84.26267418366155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77576451d994f6860889143da751ae0c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77576451d994f6860889143da751ae0c.addTo(map_5dc368ab07deca2b0065c2f23216abaa);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Adding markers

# %%
# Add a simple marker (e.g., downtown Atlanta)
folium.Marker(
    location=[33.7490, -84.3880],  # Latitude and longitude of downtown Atlanta
    popup="Downtown Atlanta",      # Message when you click the marker
    tooltip="Click me!"            # Message when you hover
).add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5dc368ab07deca2b0065c2f23216abaa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5dc368ab07deca2b0065c2f23216abaa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5dc368ab07deca2b0065c2f23216abaa = L.map(
#                 &quot;map_5dc368ab07deca2b0065c2f23216abaa&quot;,
#                 {
#                     center: [33.74719839929067, -84.26267418366155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77576451d994f6860889143da751ae0c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77576451d994f6860889143da751ae0c.addTo(map_5dc368ab07deca2b0065c2f23216abaa);
#
#
#             tile_layer_77576451d994f6860889143da751ae0c.addTo(map_5dc368ab07deca2b0065c2f23216abaa);
#
#
#             var marker_6d96bbaea61c753b9eb227f5b5f91fe7 = L.marker(
#                 [33.749, -84.388],
#                 {
# }
#             ).addTo(map_5dc368ab07deca2b0065c2f23216abaa);
#
#
#         var popup_ce422cf545674b4999bef33f9f502bc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73e887d60d95e2fa5e868f73fbf422b8 = $(`&lt;div id=&quot;html_73e887d60d95e2fa5e868f73fbf422b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Downtown Atlanta&lt;/div&gt;`)[0];
#                 popup_ce422cf545674b4999bef33f9f502bc2.setContent(html_73e887d60d95e2fa5e868f73fbf422b8);
#
#
#
#         marker_6d96bbaea61c753b9eb227f5b5f91fe7.bindPopup(popup_ce422cf545674b4999bef33f9f502bc2)
#         ;
#
#
#
#
#             marker_6d96bbaea61c753b9eb227f5b5f91fe7.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Add a circle marker (can show quantity/importance with radius or color)
folium.CircleMarker(
    location=[33.7490, -84.3880],
    radius=10,
    color='blue',
    fill=True,
    fill_color='cyan',
    fill_opacity=0.7,
    popup='Circle Marker: Downtown Atlanta'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5dc368ab07deca2b0065c2f23216abaa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5dc368ab07deca2b0065c2f23216abaa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5dc368ab07deca2b0065c2f23216abaa = L.map(
#                 &quot;map_5dc368ab07deca2b0065c2f23216abaa&quot;,
#                 {
#                     center: [33.74719839929067, -84.26267418366155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77576451d994f6860889143da751ae0c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77576451d994f6860889143da751ae0c.addTo(map_5dc368ab07deca2b0065c2f23216abaa);
#
#
#             tile_layer_77576451d994f6860889143da751ae0c.addTo(map_5dc368ab07deca2b0065c2f23216abaa);
#
#
#             var marker_6d96bbaea61c753b9eb227f5b5f91fe7 = L.marker(
#                 [33.749, -84.388],
#                 {
# }
#             ).addTo(map_5dc368ab07deca2b0065c2f23216abaa);
#
#
#         var popup_ce422cf545674b4999bef33f9f502bc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73e887d60d95e2fa5e868f73fbf422b8 = $(`&lt;div id=&quot;html_73e887d60d95e2fa5e868f73fbf422b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Downtown Atlanta&lt;/div&gt;`)[0];
#                 popup_ce422cf545674b4999bef33f9f502bc2.setContent(html_73e887d60d95e2fa5e868f73fbf422b8);
#
#
#
#         marker_6d96bbaea61c753b9eb227f5b5f91fe7.bindPopup(popup_ce422cf545674b4999bef33f9f502bc2)
#         ;
#
#
#
#
#             marker_6d96bbaea61c753b9eb227f5b5f91fe7.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_77576451d994f6860889143da751ae0c.addTo(map_5dc368ab07deca2b0065c2f23216abaa);
#
#
#             var circle_marker_8f2fb129651f18c77d5a3a4db0c76630 = L.circleMarker(
#                 [33.749, -84.388],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cyan&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5dc368ab07deca2b0065c2f23216abaa);
#
#
#         var popup_bee550ec8cefd79115b1da74d08c186f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a622897ff5deca1e77e40310130875f2 = $(`&lt;div id=&quot;html_a622897ff5deca1e77e40310130875f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Circle Marker: Downtown Atlanta&lt;/div&gt;`)[0];
#                 popup_bee550ec8cefd79115b1da74d08c186f.setContent(html_a622897ff5deca1e77e40310130875f2);
#
#
#
#         circle_marker_8f2fb129651f18c77d5a3a4db0c76630.bindPopup(popup_bee550ec8cefd79115b1da74d08c186f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Get top 5 counties by homicide rate (HR8995)
top5 = atlanta.nlargest(5, 'HR8995')

# Add circle markers for top 5 high-risk counties
for _, row in top5.iterrows():
    location = [row.geometry.centroid.y, row.geometry.centroid.x]
    rate = row['HR8995']
    name = row['NAME']
    
    folium.CircleMarker(
        location=location,
        radius=5 + rate / 5,  # size reflects homicide rate
        color='crimson',
        fill=True,
        fill_color='crimson',
        fill_opacity=0.8,
        popup=f"{name} County<br>Homicide Rate: {rate:.1f}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42671371306d4942a94e93ee3b7a5016 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42671371306d4942a94e93ee3b7a5016&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42671371306d4942a94e93ee3b7a5016 = L.map(
#                 &quot;map_42671371306d4942a94e93ee3b7a5016&quot;,
#                 {
#                     center: [33.74719839929067, -84.26267418366155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfc117086215924fff9f433386c27bc0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfc117086215924fff9f433386c27bc0.addTo(map_42671371306d4942a94e93ee3b7a5016);
#
#
#             tile_layer_dfc117086215924fff9f433386c27bc0.addTo(map_42671371306d4942a94e93ee3b7a5016);
#
#
#             var circle_marker_215c9a2ce06ff11b859399a3ae111a76 = L.circleMarker(
#                 [33.794376851373805, -84.46170362546633],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.8741844, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42671371306d4942a94e93ee3b7a5016);
#
#
#             var circle_marker_1149dae170b14fd74b4a2903bd92713a = L.circleMarker(
#                 [33.56677539744969, -82.8794568676157],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.6457608, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42671371306d4942a94e93ee3b7a5016);
#
#
#             var circle_marker_c12c33a439efd38e4d3d8b9b2cce8980 = L.circleMarker(
#                 [33.03472107126675, -84.68246877635612],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.7822674, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42671371306d4942a94e93ee3b7a5016);
#
#
#             var circle_marker_10bef4729092e7e2445d56bf8644e796 = L.circleMarker(
#                 [34.11604803883105, -82.84085097023141],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.7479574, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42671371306d4942a94e93ee3b7a5016);
#
#
#             var circle_marker_5dc393d054f451bbe8aeadd91c448760 = L.circleMarker(
#                 [32.80122338000478, -83.69308509633287],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.7419652, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_42671371306d4942a94e93ee3b7a5016);
#
#
#             var circle_marker_f66abfe20f9224e43d7abcb6adf3e3f9 = L.circleMarker(
#                 [33.794376851373805, -84.46170362546633],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOf

# %% [markdown]
# #### Adding Tooltips

# %%
from branca.element import Template, MacroElement

# %%
# Top 5 high-risk counties
top5 = atlanta.nlargest(5, 'HR8995')

# Add circle markers with tooltips and popups
# _ looping through rows, but I’m not using the index
for _, row in top5.iterrows():
    location = [row.geometry.centroid.y, row.geometry.centroid.x]
    rate = row['HR8995']
    name = row['NAME']
    
    folium.CircleMarker(
        location=location,
        radius=5 + rate / 5,
        color='crimson',
        fill=True,
        fill_color='crimson',
        fill_opacity=0.8,
        popup=folium.Popup(f"<b>{name} County</b><br>Homicide Rate: {rate:.1f}", max_width=250),
        tooltip=f"{name} County"
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84017dd83b4d7285be4559e449978bc9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84017dd83b4d7285be4559e449978bc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84017dd83b4d7285be4559e449978bc9 = L.map(
#                 &quot;map_84017dd83b4d7285be4559e449978bc9&quot;,
#                 {
#                     center: [33.74719839929067, -84.26267418366155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7b10a868b6744888013736ddbbe7387 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d7b10a868b6744888013736ddbbe7387.addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#             tile_layer_d7b10a868b6744888013736ddbbe7387.addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#             var marker_29382bff063c9c86389ebc6a3990838f = L.marker(
#                 [33.749, -84.388],
#                 {
# }
#             ).addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#         var popup_15aabd841b936c3feb511075ec9f7139 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81e54764b02b5257243ec118f7977b1c = $(`&lt;div id=&quot;html_81e54764b02b5257243ec118f7977b1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Downtown Atlanta&lt;/div&gt;`)[0];
#                 popup_15aabd841b936c3feb511075ec9f7139.setContent(html_81e54764b02b5257243ec118f7977b1c);
#
#
#
#         marker_29382bff063c9c86389ebc6a3990838f.bindPopup(popup_15aabd841b936c3feb511075ec9f7139)
#         ;
#
#
#
#
#             marker_29382bff063c9c86389ebc6a3990838f.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_d7b10a868b6744888013736ddbbe7387.addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#             var circle_marker_8d878da5152bb741ddd9b1a451fc967c = L.circleMarker(
#                 [33.749, -84.388],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cyan&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#         var popup_f712b429d91f85512463ef5153edcc48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc01ce938fe382adc685eb0eb02b7c7f = $(`&lt;div id=&quot;html_bc01ce938fe382adc685eb0eb02b7c7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Circle Marker: Downtown Atlanta&lt;/div&gt;`)[0];
#                 popup_f712b429d91f85512463ef5153edcc48.setContent(html_bc01ce938fe382adc685eb0eb02b7c7f);
#
#
#
#         circle_marker_8d878da5152bb741ddd9b1a451fc967c.bindPopup(popup_f712b429d91f85512463ef5153edcc48)
#         ;
#
#
#
#
#             tile_layer_d7b10a868b6744888013736ddbbe7387.addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#             var circle_marker_59bc9052b82f4259be9692387f55bd4d = L.circleMarker(
#                 [33.794376851373805, -84.46170362546633],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.8741844, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#         var popup_bcd36bab12e9a3c697fce2a0cf70ab80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2a49cbaeef35bf25f9417af0a0d8b7d = $(`&lt;div id=&quot;html_b2a49cbaeef35bf25f9417af0a0d8b7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fulton County&lt;br&gt;Homicide Rate: 29.4&lt;/div&gt;`)[0];
#                 popup_bcd36bab12e9a3c697fce2a0cf70ab80.setContent(html_b2a49cbaeef35bf25f9417af0a0d8b7d);
#
#
#
#         circ

# %% [markdown]
# #### Add Choropleth Layer (e.g., map by population or a variable like PO8995)

# %%
# Choose a numeric column to color counties by
value_column = 'PO8995' 

# Add interactive choropleth layer
folium.Choropleth(
    geo_data=atlanta,
    name='Choropleth',
    data=atlanta,
    columns=['NAME', value_column],  
    key_on='feature.properties.NAME',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Population in 1995'
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84017dd83b4d7285be4559e449978bc9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84017dd83b4d7285be4559e449978bc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84017dd83b4d7285be4559e449978bc9 = L.map(
#                 &quot;map_84017dd83b4d7285be4559e449978bc9&quot;,
#                 {
#                     center: [33.74719839929067, -84.26267418366155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7b10a868b6744888013736ddbbe7387 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d7b10a868b6744888013736ddbbe7387.addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#             tile_layer_d7b10a868b6744888013736ddbbe7387.addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#             var marker_29382bff063c9c86389ebc6a3990838f = L.marker(
#                 [33.749, -84.388],
#                 {
# }
#             ).addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#         var popup_15aabd841b936c3feb511075ec9f7139 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81e54764b02b5257243ec118f7977b1c = $(`&lt;div id=&quot;html_81e54764b02b5257243ec118f7977b1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Downtown Atlanta&lt;/div&gt;`)[0];
#                 popup_15aabd841b936c3feb511075ec9f7139.setContent(html_81e54764b02b5257243ec118f7977b1c);
#
#
#
#         marker_29382bff063c9c86389ebc6a3990838f.bindPopup(popup_15aabd841b936c3feb511075ec9f7139)
#         ;
#
#
#
#
#             marker_29382bff063c9c86389ebc6a3990838f.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_d7b10a868b6744888013736ddbbe7387.addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#             var circle_marker_8d878da5152bb741ddd9b1a451fc967c = L.circleMarker(
#                 [33.749, -84.388],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cyan&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#         var popup_f712b429d91f85512463ef5153edcc48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc01ce938fe382adc685eb0eb02b7c7f = $(`&lt;div id=&quot;html_bc01ce938fe382adc685eb0eb02b7c7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Circle Marker: Downtown Atlanta&lt;/div&gt;`)[0];
#                 popup_f712b429d91f85512463ef5153edcc48.setContent(html_bc01ce938fe382adc685eb0eb02b7c7f);
#
#
#
#         circle_marker_8d878da5152bb741ddd9b1a451fc967c.bindPopup(popup_f712b429d91f85512463ef5153edcc48)
#         ;
#
#
#
#
#             tile_layer_d7b10a868b6744888013736ddbbe7387.addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#             var circle_marker_59bc9052b82f4259be9692387f55bd4d = L.circleMarker(
#                 [33.794376851373805, -84.46170362546633],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.8741844, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_84017dd83b4d7285be4559e449978bc9);
#
#
#         var popup_bcd36bab12e9a3c697fce2a0cf70ab80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2a49cbaeef35bf25f9417af0a0d8b7d = $(`&lt;div id=&quot;html_b2a49cbaeef35bf25f9417af0a0d8b7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fulton County&lt;br&gt;Homicide Rate: 29.4&lt;/div&gt;`)[0];
#                 popup_bcd36bab12e

# %%
from folium.features import GeoJsonTooltip

# %%
folium.GeoJson(
    atlanta,
    name="Counties",
    tooltip=GeoJsonTooltip(fields=["NAME", value_column],
                           aliases=["County:", "Population (1995):"],
                           localize=True)
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b975ff514583b692961e0198fb077484 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b975ff514583b692961e0198fb077484&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b975ff514583b692961e0198fb077484 = L.map(
#                 &quot;map_b975ff514583b692961e0198fb077484&quot;,
#                 {
#                     center: [33.74719839929067, -84.26267418366155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63a196b0c525f5cf1196de498c21f878 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_63a196b0c525f5cf1196de498c21f878.addTo(map_b975ff514583b692961e0198fb077484);
#
#
#             tile_layer_63a196b0c525f5cf1196de498c21f878.addTo(map_b975ff514583b692961e0198fb077484);
#
#
#             var marker_83a60580464b13751fe9a92f44fb9edb = L.marker(
#                 [33.749, -84.388],
#                 {
# }
#             ).addTo(map_b975ff514583b692961e0198fb077484);
#
#
#         var popup_e9e2e19709d53af050d8b3e4e85022f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fb903e41f86b050f08fa0f7b34daf14 = $(`&lt;div id=&quot;html_1fb903e41f86b050f08fa0f7b34daf14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Downtown Atlanta&lt;/div&gt;`)[0];
#                 popup_e9e2e19709d53af050d8b3e4e85022f2.setContent(html_1fb903e41f86b050f08fa0f7b34daf14);
#
#
#
#         marker_83a60580464b13751fe9a92f44fb9edb.bindPopup(popup_e9e2e19709d53af050d8b3e4e85022f2)
#         ;
#
#
#
#
#             marker_83a60580464b13751fe9a92f44fb9edb.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_63a196b0c525f5cf1196de498c21f878.addTo(map_b975ff514583b692961e0198fb077484);
#
#
#             var circle_marker_b29fab374d26f09da5f8b47aef9e1ac6 = L.circleMarker(
#                 [33.749, -84.388],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cyan&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b975ff514583b692961e0198fb077484);
#
#
#         var popup_d9dbf180f53600d075e6591f85e2b06b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cacb9675bd6771efa391cbfef6a8e23 = $(`&lt;div id=&quot;html_3cacb9675bd6771efa391cbfef6a8e23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Circle Marker: Downtown Atlanta&lt;/div&gt;`)[0];
#                 popup_d9dbf180f53600d075e6591f85e2b06b.setContent(html_3cacb9675bd6771efa391cbfef6a8e23);
#
#
#
#         circle_marker_b29fab374d26f09da5f8b47aef9e1ac6.bindPopup(popup_d9dbf180f53600d075e6591f85e2b06b)
#         ;
#
#
#
#
#             tile_layer_63a196b0c525f5cf1196de498c21f878.addTo(map_b975ff514583b692961e0198fb077484);
#
#
#             var circle_marker_757b8b1a296c9e3c54737db8474d2eec = L.circleMarker(
#                 [33.749, -84.388],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cyan&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;:
