# %% [markdown]
# # **Blueberry Yield**

# %% [markdown]
# ## Problem Definition

# %% [markdown]
#     The most challenging task in the agricultural sector is to accurately predict crop yield. A typical machine learning algorithm often uses real data to predict crop yield. In this study, I used data generated from a deep learning model trained on the Wild Blueberry Pollination Model, a spatially explicit simulation model validated by field observation and experimental data collected in Maine USA during the last 30 years. The main aim of this study is to leverage the techniques I've learned in regression models to predict blueberry yield.
#
#     Blueberries are small, round berries with a sweet and slightly tart flavor, belonging to the genus Vaccinium. Native to North America, they have been cultivated for over a century, primarily in two types: highbush (cultivated) and lowbush (wild). Native Americans initially harvested them for food and medicinal purposes, with commercial cultivation beginning in the early 1900s through the efforts of Elizabeth White and Frederick Coville.
#
#     Today, blueberries are grown worldwide, including emerging farms in Kenya, where the climate and soil conditions are favorable. Blueberries are recognized as a superfood due to their high nutrient and antioxidant content, particularly anthocyanins, and are consumed in various forms, contributing to wellness and disease prevention diets.

# %% [markdown]
# - Fit a regression model to predict the yield of wild bluberries

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## Data Collection

# %%
# Load the test dataset

testdata=pd.read_csv(r'C:\Users\User\Desktop\Data-Science-Class\Data\test.csv')

testdata.head()
# Out:
#       id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0  15289       25.0      0.25     0.25     0.25   0.25              86.0
# 1  15290       12.5      0.25     0.25     0.75   0.63              94.6
# 2  15291       12.5      0.25     0.25     0.63   0.63              86.0
# 3  15292       25.0      0.50     0.38     0.38   0.63              86.0
# 4  15293       37.5      0.75     0.25     0.25   0.25              94.6
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              52.0                  71.9              62.0              30.0
# 1              57.2                  79.0              68.2              33.0
# 2              52.0                  71.9              62.0              30.0
# 3              52.0                  71.9              62.0              30.0
# 4              57.2                  79.0              68.2              33.0
#
# ...

# %%
# Load the train dataset

traindata=pd.read_csv(r'C:\Users\User\Desktop\Data-Science-Class\Data\train.csv')

traindata.head()
# Out:
#    id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0   0       25.0      0.50     0.25     0.75   0.50              69.7
# 1   1       25.0      0.50     0.25     0.50   0.50              69.7
# 2   2       12.5      0.25     0.25     0.63   0.63              86.0
# 3   3       12.5      0.25     0.25     0.63   0.50              77.4
# 4   4       25.0      0.50     0.25     0.63   0.63              77.4
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              42.1                  58.2              50.2              24.3
# 1              42.1                  58.2              50.2              24.3
# 2              52.0                  71.9              62.0              30.0
# 3              46.8                  64.7              55.8              27.0
# 4              46.8                  64.7              55.8              27.0
#
# ...

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %%
# Step 1- check for data type consistency

testdata.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10194 non-null  int64
#  1   clonesize             10194 non-null  float64
#  2   honeybee              10194 non-null  float64
#  3   bumbles               10194 non-null  float64
#  4   andrena               10194 non-null  float64
#  5   osmia                 10194 non-null  float64
#  6   MaxOfUpperTRange      10194 non-null  float64
#  7   MinOfUpperTRange      10194 non-null  float64
#  8   AverageOfUpperTRange  10194 non-null  float64
#  9   MaxOfLowerTRange      10194 non-null  float64
#  10  MinOfLowerTRange      10194 non-null  float64
#  11  AverageOfLowerTRange  10194 non-null  float64
#  12  RainingDays           10194 non-null  float64
#  13  AverageRainingDays    10194 non-null  float64
#  14  fruitset              10194 non-null  float64
# ...

# %%
# Step 1- check for data type consistency

traindata.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15289 entries, 0 to 15288
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    15289 non-null  int64
#  1   clonesize             15289 non-null  float64
#  2   honeybee              15289 non-null  float64
#  3   bumbles               15289 non-null  float64
#  4   andrena               15289 non-null  float64
#  5   osmia                 15289 non-null  float64
#  6   MaxOfUpperTRange      15289 non-null  float64
#  7   MinOfUpperTRange      15289 non-null  float64
#  8   AverageOfUpperTRange  15289 non-null  float64
#  9   MaxOfLowerTRange      15289 non-null  float64
#  10  MinOfLowerTRange      15289 non-null  float64
#  11  AverageOfLowerTRange  15289 non-null  float64
#  12  RainingDays           15289 non-null  float64
#  13  AverageRainingDays    15289 non-null  float64
#  14  fruitset              15289 non-null  float64
# ...

# %% [markdown]
# - All data is numerical so we dont need to encode
# -

# %%
#Step 2- Check for missing values

testdata.isnull().sum()
# Out:
# id                      0
# clonesize               0
# honeybee                0
# bumbles                 0
# andrena                 0
# osmia                   0
# MaxOfUpperTRange        0
# MinOfUpperTRange        0
# AverageOfUpperTRange    0
# MaxOfLowerTRange        0
# MinOfLowerTRange        0
# AverageOfLowerTRange    0
# RainingDays             0
# AverageRainingDays      0
# fruitset                0
# fruitmass               0
# seeds                   0
# dtype: int64

# %%
#Step 2- Check for missing values

traindata.isnull().sum()
# Out:
# id                      0
# clonesize               0
# honeybee                0
# bumbles                 0
# andrena                 0
# osmia                   0
# MaxOfUpperTRange        0
# MinOfUpperTRange        0
# AverageOfUpperTRange    0
# MaxOfLowerTRange        0
# MinOfLowerTRange        0
# AverageOfLowerTRange    0
# RainingDays             0
# AverageRainingDays      0
# fruitset                0
# fruitmass               0
# seeds                   0
# yield                   0
# dtype: int64

# %% [markdown]
# - No missing values

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Feature Engineering and Selection

# %% [markdown]
# ## Model Selection

# %% [markdown]
# ## Model Training

# %% [markdown]
# ## Model Evaluation and Tuning
